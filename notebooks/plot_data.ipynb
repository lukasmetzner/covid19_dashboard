# %%
import pandas as pd
import plotly.express as px
import scipy.signal as sig

df_cases = pd.read_csv("../cases_transformed.csv")
df_deaths = pd.read_csv("../deaths_transformed.csv")
df_recovered = pd.read_csv("../recovered_transformed.csv")

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=2)
fig.append_trace(go.Line(x=df_cases.date.values, y=df_cases.new_cases.values, name="Cases"), row=1, col=1)
fig.append_trace(go.Line(x=df_cases.date.values, y=sig.savgol_filter(df_cases.new_cases, 23, 5), name="Cases Smoothed"), row=1, col=2)

fig.append_trace(go.Line(x=df_deaths.date.values, y=df_deaths.new_deaths.values, name="Deaths"), row=2, col=1)
fig.append_trace(go.Line(x=df_deaths.date.values, y=sig.savgol_filter(df_deaths.new_deaths, 23, 5), name="Deaths Smoothed"), row=2, col=2)

fig.append_trace(go.Line(x=df_recovered.date.values, y=df_recovered.new_recovered.values, name="Recovered Smoothed"), row=3, col=1)
fig.append_trace(go.Line(x=df_recovered.date.values, y=sig.savgol_filter(df_recovered.new_recovered, 23, 5), name="Recovered"), row=3, col=2)
fig.update_layout(height=600, width=800, title_text="Smoothed and raw corona data")
fig.show()
# Out:
# /Users/lukasmetzner/anaconda3/lib/python3.8/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
df_deaths.head()
# Out:
#          date  abs_deaths  new_deaths
# 0  2020-01-22           0         0.0
# 1  2020-01-23           0         0.0
# 2  2020-01-24           0         0.0
# 3  2020-01-25           0         0.0
# 4  2020-01-26           0         0.0

# %%
df_merged = df_cases.merge(df_deaths)
df_merged.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b35a3261ac48> in <module>
# ----> 1 df_merged = df_cases.merge(df_deaths, by="date")
#       2 df_merged.head()
#
# TypeError: merge() got an unexpected keyword argument 'by'
